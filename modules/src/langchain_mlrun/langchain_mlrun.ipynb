# %% [markdown]
# # LangChain ✕ MLRun Integration
#
# `langchain_mlrun` is a hub module that implements LangChain integration with MLRun. Using the module allows MLRun to orchestrate LangChain and LangGraph code, enabling tracing and monitoring batch workflows and realtime deployments.
# ___

# %% [markdown]
# ## Main Components
#
# This is a short brief of the components available to import from the `langchain_mlrun` module. For full docs, see the documentation page.
#
# ### Settings
#
# The module uses Pydantic settings classes that can be configured programmatically or via environment variables. The main class is `MLRunTracerSettings`. It contains two sub-settings:
# * `MLRunTracerClientSettings` - Connection settings (stream path, container, endpoint info). Env prefix: `"MLRUN_TRACER_CLIENT_"`
# * `MLRunTracerMonitorSettings` - Controls what/how runs are captured (filters, labels, debug mode). Env prefix: `"MLRUN_TRACER_MONITOR_"`
#
# For more information about each setting, see the class docstrings.
#
# #### Example - via code configuration
#
# ```python
# from langchain_mlrun import MLRunTracerSettings, MLRunTracerClientSettings, MLRunTracerMonitorSettings
#
# settings = MLRunTracerSettings(
#     client=MLRunTracerClientSettings(
#         stream_path="my-project/model-endpoints/stream-v1",
#         container="projects",
#         model_endpoint_name="my_endpoint",
#         model_endpoint_uid="abc123",
#         serving_function="my_function",
#     ),
#     monitor=MLRunTracerMonitorSettings(
#         label="production",
#         root_run_only=True,  # Only monitor root runs, not child runs
#         tags_filter=["important"],  # Only monitor runs with this tag
#     ),
# )
# ```
#
# #### Example - environment variable configuration
#
# ```bash
# export MLRUN_TRACER_CLIENT_STREAM_PATH="my-project/model-endpoints/stream-v1"
# export MLRUN_TRACER_CLIENT_CONTAINER="projects"
# export MLRUN_TRACER_MONITOR_LABEL="production"
# export MLRUN_TRACER_MONITOR_ROOT_RUN_ONLY="true"
# ```
#
# ### MLRun Tracer
#
# `MLRunTracer` is a LangChain-compatible tracer that converts LangChain `Run` objects into MLRun monitoring events and publishes them to a V3IO stream.
#
# Key points:
# * **No inheritance required** - use it directly without subclassing.
# * **Fully customizable via settings** - control filtering, summarization, and output format.
# * **Custom summarizer support** - pass your own `run_summarizer_function` via settings to customize how runs are converted to events.
#
# ### Monitoring Setup Utility Function
#
# `setup_langchain_monitoring()` is a utility function that creates the necessary MLRun infrastructure for LangChain monitoring. This is a **temporary workaround** until custom endpoint creation support is added to MLRun.
#
# The function returns a dictionary of environment variables to configure auto-tracing. See how to use it in the tutorial section below.
#
# ### LangChain Monitoring Application
#
# `LangChainMonitoringApp` is a base class (inheriting from MLRun's `ModelMonitoringApplicationBase`) for building monitoring applications that process events from the MLRun Tracer.
#
# It offers several built-in helper methods and metrics for analyzing LangChain runs:
#
# * Helper methods:
#   * `get_structured_runs()` - Parse raw monitoring samples into structured run dictionaries with filtering options
#   * `iterate_structured_runs()` - Iterate over all runs including nested child runs
# * Metric methods:
#   * `calculate_average_latency()` - Average latency across root runs
#   * `calculate_success_rate()` - Percentage of runs without errors
#   * `count_token_usage()` - Total input/output tokens from LLM runs
#   * `count_run_names()` - Count occurrences of each run name
#
# The base app can be used as-is, but it is recommended to extend it with your own custom monitoring logic.
# ___

# %% [markdown]
# ## How to Apply MLRun?
#
# ### Auto Tracing
#
# Auto tracing automatically instruments all LangChain code by setting the `MLRUN_MONITORING_ENABLED` environment variable and importing the module:
#
# ```python
# import os
# os.environ["MLRUN_MONITORING_ENABLED"] = "1"
# # Set other MLRUN_TRACER_* environment variables as needed...
#
# # Import the module BEFORE any LangChain code
# langchain_mlrun = mlrun.import_module("hub://langchain_mlrun")
#
# # All LangChain/LangGraph code below will be automatically traced
# chain.invoke(...)
# ```
#
# ### Manual Tracing
#
# For more control, use the `mlrun_monitoring()` context manager to trace specific code blocks:
#
# ```python
# from langchain_mlrun import mlrun_monitoring, MLRunTracerSettings
#
# # Optional: customize settings
# settings = MLRunTracerSettings(...)
#
# with mlrun_monitoring(settings=settings) as tracer:
#     # Only LangChain code within this block will be traced
#     result = chain.invoke({"topic": "MLRun"})
# ```
# ___

# %% [markdown]
# ## Tutorial
#
# In this tutorial we'll show how to orchestrate LangChain based code with MLRun using the `langchain_mlrun` hub module.
#
# ### Prerequisites
#
# Install MLRun and the `langchain_mlrun` requirements.

# %%
# !pip install mlrun langchain pydantic-settings kafka-python orjson uuid-utils
# Out:
# Requirement already satisfied: mlrun in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (1.10.0)
# Requirement already satisfied: langchain in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (1.2.6)
# Requirement already satisfied: pydantic-settings in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: kafka-python in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: orjson in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (3.11.5)
# Requirement already satisfied: uuid-utils in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: urllib3>=1.26.20 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2.6.3)
# Requirement already satisfied: v3io-frames~=0.13.11 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.13.13)
# Requirement already satisfied: GitPython>=3.1.41,~=3.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (3.1.46)
# Requirement already satisfied: aiohttp~=3.11 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (3.13.3)
# Requirement already satisfied: aiohttp-retry~=2.9 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2.9.1)
# Requirement already satisfied: click~=8.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (8.3.1)
# Requirement already satisfied: nest-asyncio~=1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.6.0)
# Requirement already satisfied: ipython~=8.10 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (8.38.0)
# Requirement already satisfied: nuclio-jupyter~=0.11.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.11.3)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2.1.4)
# Requirement already satisfied: pyarrow<18,>=10.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (17.0.0)
# Requirement already satisfied: pyyaml<7,>=6.0.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (6.0.3)
# Requirement already satisfied: requests~=2.32 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2.32.5)
# Requirement already satisfied: tabulate~=0.8.6 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.8.10)
# Requirement already satisfied: v3io~=0.7.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.7.2)
# Requirement already satisfied: pydantic>=1.10.15 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2.12.5)
# Requirement already satisfied: mergedeep~=1.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.3.4)
# Requirement already satisfied: semver~=3.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (3.0.4)
# Requirement already satisfied: dependency-injector~=4.41 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (4.48.3)
# Requirement already satisfied: fsspec<=2025.7.0,>=2025.5.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (2025.7.0)
# Requirement already satisfied: v3iofs~=0.1.17 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.1.18)
# Requirement already satisfied: storey~=1.10.16 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.10.20)
# Requirement already satisfied: inflection~=0.5.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.5.1)
# Requirement already satisfied: python-dotenv~=1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.2.1)
# Requirement already satisfied: setuptools>=75.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (80.10.1)
# Requirement already satisfied: deprecated~=1.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (1.3.1)
# Requirement already satisfied: jinja2>=3.1.6,~=3.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (3.1.6)
# Requirement already satisfied: mlrun-pipelines-kfp-common~=0.5.9 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.5.9)
# Requirement already satisfied: mlrun-pipelines-kfp-v1-8~=0.5.8 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.5.9)
# Requirement already satisfied: docstring_parser~=0.16 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (0.17.0)
# Requirement already satisfied: aiosmtplib~=3.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (3.0.2)
# Requirement already satisfied: deepdiff<9.0.0,>=8.6.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun) (8.6.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain) (1.0.6)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pydantic-settings) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from aiohttp~=3.11->mlrun) (1.22.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from deepdiff<9.0.0,>=8.6.1->mlrun) (5.5.0)
# Requirement already satisfied: typing-extensions in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from dependency-injector~=4.41->mlrun) (4.15.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from deprecated~=1.2->mlrun) (1.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from GitPython>=3.1.41,~=3.1->mlrun) (4.0.12)
# Requirement already satisfied: decorator in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (2.19.2)
# Requirement already satisfied: stack_data in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipython~=8.10->mlrun) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jinja2>=3.1.6,~=3.1->mlrun) (3.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.1.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: kfp_server_api~=1.8 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.5.9->mlrun) (1.8.5)
# Requirement already satisfied: kubernetes>=25.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from mlrun-pipelines-kfp-common~=0.5.9->mlrun) (35.0.0)
# Requirement already satisfied: nbconvert>=6.4.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.2->mlrun) (7.16.6)
# Requirement already satisfied: boto3>=1.28.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.2->mlrun) (1.42.30)
# Requirement already satisfied: importlib-metadata<8.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.2->mlrun) (7.2.1)
# Requirement already satisfied: jupyter-server>=2.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.2->mlrun) (2.17.0)
# Requirement already satisfied: ipykernel>=5.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nuclio-jupyter~=0.11.2->mlrun) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pandas<2.2,>=1.2->mlrun) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pydantic>=1.10.15->mlrun) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from requests~=2.32->mlrun) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from requests~=2.32->mlrun) (2026.1.4)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from storey~=1.10.16->mlrun) (0.6.2)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from v3io-frames~=0.13.11->mlrun) (1.72.0)
# Requirement already satisfied: grpcio-tools>=1.49 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from v3io-frames~=0.13.11->mlrun) (1.76.0)
# Requirement already satisfied: protobuf<7,>=4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from v3io-frames~=0.13.11->mlrun) (6.33.4)
# Requirement already satisfied: botocore<1.43.0,>=1.42.30 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.2->mlrun) (1.42.34)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.2->mlrun) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from boto3>=1.28.0->nuclio-jupyter~=0.11.2->mlrun) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.41,~=3.1->mlrun) (5.0.2)
# Requirement already satisfied: grpcio>=1.76.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from grpcio-tools>=1.49->v3io-frames~=0.13.11->mlrun) (1.76.0)
# Requirement already satisfied: zipp>=0.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from importlib-metadata<8.0.0->nuclio-jupyter~=0.11.2->mlrun) (3.23.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.8.19)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (5.9.1)
# Requirement already satisfied: psutil>=5.7 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython~=8.10->mlrun) (0.8.5)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (3.0.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.9.0)
# Requirement already satisfied: six>=1.10 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from kfp_server_api~=1.8->mlrun-pipelines-kfp-common~=0.5.9->mlrun) (1.17.0)
# Requirement already satisfied: requests-oauthlib in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.5.9->mlrun) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.5.9->mlrun) (0.10)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.25.0)
# Requirement already satisfied: beautifulsoup4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython~=8.10->mlrun) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython~=8.10->mlrun) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from stack_data->ipython~=8.10->mlrun) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (25.1.0)
# Requirement already satisfied: webencodings in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (1.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.0.0->nuclio-jupyter~=0.11.2->mlrun) (4.5.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (4.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (4.0.0)
# Requirement already satisfied: referencing in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.37.0)
# Requirement already satisfied: rfc3339-validator in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (2.21.2)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.11.2->mlrun) (2.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=25.3->mlrun-pipelines-kfp-common~=0.5.9->mlrun) (3.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (0.30.0)
# Requirement already satisfied: fqdn in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.1.0)
# Requirement already satisfied: uri-template in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (2.0.0)
# Requirement already satisfied: pycparser in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Tomer_Weitzman/PycharmProjects/functions/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2.0.0->nuclio-jupyter~=0.11.2->mlrun) (1.4.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Local Development Setup (Optional)
#
# **Skip this section if you're running inside a Jupyter instance deployed in the MLRun cluster.**
#
# If you're running this notebook from your local machine (outside the cluster), you need to:
#
# 1. **Set up port-forwarding** to access cluster services:
# ```bash
# # MLRun API
# kubectl port-forward -n mlrun svc/mlrun-api 30070:8080
#
# # MinIO (S3-compatible storage)
# kubectl port-forward -n mlrun svc/minio 9000:9000
#
# # Kafka (for CE mode) - requires /etc/hosts entry: 127.0.0.1 kafka-stream
# kubectl port-forward -n mlrun svc/kafka-stream 9092:9092
#
# # TDEngine (for CE mode) - requires /etc/hosts entry: 127.0.0.1 tdengine-tsdb
# kubectl port-forward -n mlrun svc/tdengine-tsdb 6041:6041
# ```
#
# 2. **Run the cell below** to configure environment variables for local access.

# %%
# === LOCAL DEVELOPMENT ONLY ===
# Uncomment and run this cell if running outside the cluster

import os

# MLRun API endpoint (via port-forward)
os.environ["MLRUN_DBPATH"] = "http://localhost:30070"

# MinIO/S3 credentials and endpoint (via port-forward)
# Set these environment variables before running the notebook:
#   export AWS_ACCESS_KEY_ID="<your-minio-access-key>"
#   export AWS_SECRET_ACCESS_KEY="<your-minio-secret-key>"
#   export AWS_ENDPOINT_URL_S3="<s3-endpoint-url>"

print("Local development environment configured!")
# Out:
# Local development environment configured!

# %% [markdown]
# ### Create Project
#
# We'll first create an MLRun project

# %%
import os
import time
import datetime
import mlrun

print(f"MLRun version: {mlrun.__version__}")
print(f"CE Mode: {mlrun.mlconf.is_ce_mode()}")

project = mlrun.get_or_create_project("langchain-mlrun-tutorial")
print(f"Project: {project.name}")
# Out:
# MLRun version: 1.10.0
# CE Mode: True
# > 2026-02-03 18:35:31,866 [info] Loading project from path: {"path":"./","project_name":"langchain-mlrun-tutorial","user_project":false}
# > 2026-02-03 18:35:31,892 [info] Project loaded successfully: {"path":"./","project_name":"langchain-mlrun-tutorial","stored_in_db":true}
# Project: langchain-mlrun-tutorial

# %% [markdown]
# ### Enable Monitoring
#
# To use MLRun's monitoring feature in our project we first need to set up the monitoring infrastructure.
#
# - **MLRun CE**: Uses Kafka for streaming (automatically detected)
# - **MLRun Enterprise**: Uses V3IO for streaming (automatically detected)
#
# The cell below automatically detects your MLRun mode and sets up the appropriate streaming infrastructure.

# %%
# Configuration - set these environment variables before running in CE mode:
#   export KAFKA_BROKER="<kafka-broker-address>"
#   export TDENGINE_HOST="<tdengine-host>"
#   export TDENGINE_PORT="<tdengine-port>"
#   export TDENGINE_USER="<tdengine-username>"
#   export TDENGINE_PASSWORD="<tdengine-password>"

# Enable monitoring based on MLRun mode (CE or Enterprise)
if mlrun.mlconf.is_ce_mode():
    print("Setting up Kafka streaming for MLRun CE...")
    from mlrun.datastore.datastore_profile import DatastoreProfileKafkaStream, DatastoreProfileTDEngine
    
    stream_profile = DatastoreProfileKafkaStream(
        name="kafka-stream-profile",
        brokers=os.environ["KAFKA_BROKER"],
        topics=[],
    )
    tsdb_profile = DatastoreProfileTDEngine(
        name="tsdb-profile",
        user=os.environ["TDENGINE_USER"],
        password=os.environ["TDENGINE_PASSWORD"],
        host=os.environ["TDENGINE_HOST"],
        port=int(os.environ["TDENGINE_PORT"]),
    )
    project.register_datastore_profile(stream_profile)
    project.register_datastore_profile(tsdb_profile)
else:
    print("Setting up V3IO streaming for MLRun Enterprise...")
    from mlrun.datastore import DatastoreProfileV3io
    
    stream_profile = DatastoreProfileV3io(name="v3io-ds", v3io_access_key=os.environ["V3IO_ACCESS_KEY"])
    tsdb_profile = stream_profile
    project.register_datastore_profile(stream_profile)

project.set_model_monitoring_credentials(
    stream_profile_name=stream_profile.name,
    tsdb_profile_name=tsdb_profile.name,
)

project.enable_model_monitoring(
    base_period=1,
    wait_for_deployment=True,
)

print("Monitoring enabled successfully!")
# Out:
# Setting up Kafka streaming for MLRun CE...
# > 2026-02-03 18:35:34,469 [warning] enable_model_monitoring: 'base_period' < 10 minutes is not supported in production environments: {"project":"langchain-mlrun-tutorial"}
# 2026-02-03 16:35:38  (info) Deploying function
# 2026-02-03 16:35:38  (info) Building
# 2026-02-03 16:35:38  (info) Staging files and preparing base images
# 2026-02-03 16:35:38  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:35:39  (info) Building processor image
# 2026-02-03 16:38:19  (info) Build complete
# 2026-02-03 16:38:33  (info) Function deploy complete
# 2026-02-03 16:35:34  (info) Deploying function
# 2026-02-03 16:35:34  (info) Building
# 2026-02-03 16:35:35  (info) Staging files and preparing base images
# 2026-02-03 16:35:35  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:35:35  (info) Building processor image
# 2026-02-03 16:38:15  (info) Build complete
# 2026-02-03 16:38:41  (info) Function deploy complete
# 2026-02-03 16:35:36  (info) Deploying function
# 2026-02-03 16:35:36  (info) Building
# 2026-02-03 16:35:36  (info) Staging files and preparing base images
# 2026-02-03 16:35:36  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:35:37  (info) Building processor image
# 2026-02-03 16:38:47  (info) Build complete
# 2026-02-03 16:38:59  (info) Function deploy complete
# 2026-02-03 16:35:40  (info) Deploying function
# 2026-02-03 16:35:40  (info) Building
# 2026-02-03 16:35:40  (info) Staging files and preparing base images
# 2026-02-03 16:35:40  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:35:41  (info) Building processor image
# 2026-02-03 16:38:41  (info) Build complete
# 2026-02-03 16:38:53  (info) Function deploy complete
# Monitoring enabled successfully!

# %% [markdown]
# ### Import `langchain_mlrun`
#
# Now we'll import `langchain_mlrun` from the hub.

# %%
# Import the module from the hub:
langchain_mlrun = mlrun.import_module("hub://langchain_mlrun")

# Import the utility function and monitoring application from the module:
setup_langchain_monitoring = langchain_mlrun.setup_langchain_monitoring
LangChainMonitoringApp = langchain_mlrun.LangChainMonitoringApp

# %%
# Import the module locally (since it's not yet on the hub)
import sys
import os

# Get the directory of the notebook
notebook_dir = os.getcwd()
print(f"Loading langchain_mlrun from: {notebook_dir}")

# Add the directory to Python path if not already there
if notebook_dir not in sys.path:
    sys.path.insert(0, notebook_dir)

# Import the module
import langchain_mlrun

# Import the utility function and monitoring application from the module:
setup_langchain_monitoring = langchain_mlrun.setup_langchain_monitoring
LangChainMonitoringApp = langchain_mlrun.LangChainMonitoringApp

print("✓ Module loaded successfully!")
# Out:
# Loading langchain_mlrun from: /Users/Tomer_Weitzman/PycharmProjects/functions/modules/src/langchain_mlrun
# ✓ Module loaded successfully!

# %% [markdown]
# ### Create Monitorable Endpoint
#
# Endpoints are the entities being monitored by MLRun. We'll use the `setup_langchain_monitoring()` utility function to create the model monitoring endpoint.
#
# For MLRun CE mode, you must pass the `kafka_stream_profile_name` parameter with the name of the registered Kafka stream profile.
#
# By default, the endpoint name will be `"langchain_mlrun_endpoint"` but you can change it by using the `model_endpoint_name` parameter.

# %%
# Pass kafka_stream_profile_name for CE mode (required)
env_vars = setup_langchain_monitoring(
    kafka_stream_profile_name=stream_profile.name if mlrun.mlconf.is_ce_mode() else None
)
# Out:
# Creating LangChain model endpoint
#
#   [✓] Loading Project......................... Done (0.00s)
#   [✓] Creating Model.......................... Done (0.10s)
#   [✓] Creating Function....................... Done (0.05s)
#   [✓] Creating Model Endpoint................. Done (0.09s)
#
# ✨ Done! LangChain monitoring model endpoint created successfully.
# You can now set the following environment variables to enable MLRun tracing in your LangChain code:
#
# {
#     "MLRUN_MONITORING_ENABLED": "1",
#     "MLRUN_TRACER_CLIENT_PROJECT": "langchain-mlrun-tutorial",
#     "MLRUN_TRACER_CLIENT_MODEL_ENDPOINT_NAME": "langchain_mlrun_endpoint",
#     "MLRUN_TRACER_CLIENT_MODEL_ENDPOINT_UID": "b143379099da46219133d9817160dc97",
#     "MLRUN_TRACER_CLIENT_SERVING_FUNCTION": "langchain_mlrun_function",
#     "MLRUN_TRACER_CLIENT_KAFKA_STREAM_PROFILE_NAME": "kafka-stream-profile"
# }
#
# To customize the monitoring behavior, you can also set additional environment variables prefixed with 'MLRUN_TRACER_MONITOR_'. Refer to the MLRun tracer documentation for more details.

# %% [markdown]
# ### Setup Environment Variables for Auto Tracing
#
# We'll use the environment variables returned from `setup_langchain_monitoring` to setup the environment for auto-tracing. Read the printed outputs for more information.

# %%
os.environ.update(env_vars)

# %% [markdown]
# ### Run `langchain` or `langgraph` Code
#
# Here we have 3 functions, each using different method utilizing LLMs with `langchain` and `langgraph`:
# * `run_simple_chain` - Using `langchain`'s chains.
# * `run_simple_agent` - Using `langchain`'s `create_agent` function and `tool`s.
# * `run_langgraph_graph` - Using pure `langgraph`.
#
# > **Notice**: You don't need to set OpenAI API credentials, there is a mock `ChatModel` that will replace it if the credentials are not set in the environment. If you wish to use OpenAI models, make sure you `pip install langchain_openai` and set the `OPENAI_API_KEY` environment variable before continue to the next cell.
#
# Because the auto-tracing environment is set, any run will be automatically traced and monitored!
#
# Feel free to adjust the code as you like.
#
# > **Remember**: To enable auto-tracing you do need to set the environment variables and import the `langchain_mlrun` module before any LangChain code. For batch jobs and realtime functions, make sure you set env vars in the MLRun function and add the import line `langchain_mlrun = mlrun.import_module("hub://langchain_mlrun")` at the top of your code.

# %%
import os
from typing import Literal, TypedDict, Annotated, Sequence, Any, Callable
from operator import add

from langchain_core.language_models import LanguageModelInput
from langchain_core.runnables import Runnable, RunnableLambda
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.language_models.fake_chat_models import FakeListChatModel, GenericFakeChatModel
from langchain.agents import create_agent
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.tools import tool, BaseTool

from langgraph.graph import StateGraph, START, END
from langchain_core.messages import BaseMessage


def _check_openai_credentials() -> bool:
    """
    Check if OpenAI API key is set in environment variables.

    :return: True if OPENAI_API_KEY is set, False otherwise.
    """
    return "OPENAI_API_KEY" in os.environ


# Import ChatOpenAI only if OpenAI credentials are available (meaning `langchain-openai` must be installed).
if _check_openai_credentials():
    from langchain_openai import ChatOpenAI

    
class _ToolEnabledFakeModel(GenericFakeChatModel):
    """
    A fake chat model that supports tool binding for running agent tracing tests.
    """

    def bind_tools(
        self,
        tools: Sequence[
            dict[str, Any] | type | Callable | BaseTool  # noqa: UP006
        ],
        *,
        tool_choice: str | None = None,
        **kwargs: Any,
    ) -> Runnable[LanguageModelInput, AIMessage]:
        return self


#: Tag value for testing tag filtering.
_dummy_tag = "dummy_tag"


def run_simple_chain() -> str:
    """
    Run a simple LangChain chain that gets a fact about a topic.
    """
    # Build a simple chain: prompt -> llm -> str output parser
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        tags=[_dummy_tag]
    ) if _check_openai_credentials() else (
        FakeListChatModel(
            responses=[
                "MLRun is an open-source orchestrator for machine learning pipelines."
            ],
            tags=[_dummy_tag]
        )
    )
    prompt = ChatPromptTemplate.from_template("Tell me a short fact about {topic}")
    chain = prompt | llm | StrOutputParser()

    # Run the chain:
    response = chain.invoke({"topic": "MLRun"})
    return response


def run_simple_agent():
    """
    Run a simple LangChain agent that uses two tools to get weather and stock price.
    """
    # Define the tools:
    @tool
    def get_weather(city: str) -> str:
        """Get the current weather for a specific city."""
        return f"The weather in {city} is 22°C and sunny."

    @tool
    def get_stock_price(symbol: str) -> str:
        """Get the current stock price for a symbol."""
        return f"The stock price for {symbol} is $150.25."

    # Define the model:
    model = ChatOpenAI(
        model="gpt-4o-mini",
        tags=[_dummy_tag]
    ) if _check_openai_credentials() else (
        _ToolEnabledFakeModel(
            messages=iter(
                [
                    AIMessage(
                        content="",
                        tool_calls=[
                            {"name": "get_weather", "args": {"city": "London"}, "id": "call_abc123"},
                            {"name": "get_stock_price", "args": {"symbol": "AAPL"}, "id": "call_def456"}
                        ]
                    ),
                    AIMessage(content="The weather in London is 22°C and AAPL is trading at $150.25.")
                ]
            ),
            tags=[_dummy_tag]
        )
    )

    # Create the agent:
    agent = create_agent(
        model=model,
        tools=[get_weather, get_stock_price],
        system_prompt="You are a helpful assistant with access to tools."
    )

    # Run the agent:
    return agent.invoke({"messages": ["What is the weather in London and the stock price of AAPL?"]})


def run_langgraph_graph():
    """
    Run a LangGraph agent that uses reflection to correct its answer.
    """
    # Define the graph state:
    class AgentState(TypedDict):
        messages: Annotated[list[BaseMessage], add]
        attempts: int

    # Define the model:
    model = ChatOpenAI(model="gpt-4o-mini") if _check_openai_credentials() else (
        _ToolEnabledFakeModel(
            messages=iter(
                [
                    AIMessage(content="There are 2 'r's in Strawberry."),  # Mocking the failure
                    AIMessage(content="I stand corrected. S-t-r-a-w-b-e-r-r-y. There are 3 'r's."),  # Mocking the fix
                ]
            )
        )
    )

    # Define the graph nodes and router:
    def call_model(state: AgentState):
        response = model.invoke(state["messages"])
        return {"messages": [response], "attempts": state["attempts"] + 1}

    def reflect_node(state: AgentState):
        prompt = "Wait, count the 'r's again slowly, letter by letter. Are you sure?"
        return {"messages": [HumanMessage(content=prompt)]}

    def router(state: AgentState) -> Literal["reflect", END]:
        # Make sure there are 2 attempts at least for an answer:
        if state["attempts"] == 1:
            return "reflect"
        return END

    # Build the graph:
    builder = StateGraph(AgentState)
    builder.add_node("model", call_model)
    tagged_reflect_node = RunnableLambda(reflect_node).with_config(tags=[_dummy_tag])
    builder.add_node("reflect", tagged_reflect_node)
    builder.add_edge(START, "model")
    builder.add_conditional_edges("model", router)
    builder.add_edge("reflect", "model")
    graph = builder.compile()

    # Run the graph:
    return graph.invoke({"messages": [HumanMessage(content="How many 'r's in Strawberry?")], "attempts": 0})

# %% [markdown]
# Let's create some traffic, we'll run whatever function you want in a loop to get some events. We take timestamps in order to use them later to run the monitoring application on the data we'll send.

# %%
# Run LangChain code and now it should be tracked and monitored in MLRun:
start_timestamp = datetime.datetime.now() - datetime.timedelta(minutes=1)
for i in range(20):
    run_simple_agent()
end_timestamp = datetime.datetime.now() + datetime.timedelta(minutes=5)

# %% [markdown]
# > **Note**: Please wait a minute or two until the events are processed.

# %%
time.sleep(60)

# %% [markdown]
# ### Test the LangChain Monitoring Application
#
# To test a monitoring application, we use the `evaluate` class method. We'll run an evaluation on the data we just sent. It is a small local job and should run fast.
#
# Keep an eye for the returned metrics from the monitoring application.

# %%
LangChainMonitoringApp.evaluate(
    func_name="langchain-monitoring-app-test",
    func_path="langchain_mlrun.py",
    run_local=True,
    endpoints=[env_vars["MLRUN_TRACER_CLIENT_MODEL_ENDPOINT_NAME"]],
    start=start_timestamp.isoformat(),
    end=end_timestamp.isoformat(),
)
# Out:
# > 2026-02-03 18:44:02,620 [info] Changing function name - adding `"-batch"` suffix: {"func_name":"langchain-monitoring-app-test-batch"}
# > 2026-02-03 18:44:02,753 [warning] It is recommended to use k8s secret (specify secret_name), specifying aws_access_key/aws_secret_key directly is unsafe.
# > 2026-02-03 18:44:02,770 [info] Storing function: {"db":"http://localhost:30070","name":"langchain-monitoring-app-test-batch--handler","uid":"770895d90dfe4bef8fa8c5567a92c6f9"}
# > 2026-02-03 18:44:04,427 [warning] No data was found for any of the specified endpoints. No results were produced: {"application_name":"langchain-monitoring-app-test-batch","end":"2026-02-03T18:47:58.586764","endpoints":["langchain_mlrun_endpoint"],"start":"2026-02-03T18:41:58.248081"}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#
#   // Get the base URL of the current notebook
#   var baseUrl = window.location.origin;
#
#   // Construct the full URL
#   var fullUrl = new URL(el.title, baseUrl).href;
#
#   document.querySelector(panelName + "-title").innerHTML = fullUrl
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (fullUrl.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", fullUrl);
#   oReq.send();
#
#
#   //iframe.src = fullUrl;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>end</th>
#       <th>state</th>
#       <th>kind</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>langchain-mlrun-tutorial</td>
#       <td><div title="770895d90dfe4bef8fa8c5567a92c6f9">...92c6f9</div></td>
#       <td>0</td>
#       <td>Feb 03 16:44:02</td>
#       <td>NaT</td>
#       <td>completed</td>
#       <td>run</td>
#       <td>langchain-monitoring-app-test-batch--handler</td>
#       <td><div class="dictlist">kind=local</div><div class="dictlist">owner=Tomer_Weitzman</div><div class="dictlist">host=M-QXN63PHMF9</div></td>
#       <td></td>
#       <td><div class="dictlist">endpoints=['langchain_mlrun_endpoint']</div><div class="dictlist">start=2026-02-03T18:41:58.248081</div><div class="dictlist">end=2026-02-03T18:47:58.586764</div><div class="dictlist">base_period=None</div><div class="dictlist">write_output=False</div><div class="dictlist">existing_data_handling=fail_on_overlap</div><div class="dictlist">stream_profile=None</div></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result74beab0a-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result74beab0a-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result74beab0a" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result74beab0a-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2026-02-03 18:44:04,491 [info] Run execution finished: {"name":"langchain-monitoring-app-test-batch--handler","status":"completed"}

# %% [markdown]
# ### Deploy the Monitoring Application
#
# All that's left to do now is to deploy our monitoring application!

# %%
# For MLRun CE mode running locally, we need to set the in-cluster MinIO endpoint
# Using double-deploy workaround: deploy first, then set env var and deploy again

# First deploy:
LangChainMonitoringApp.deploy(
    func_name="langchain-monitoring-app",
    func_path="langchain_mlrun.py",
    image="mlrun/mlrun",
    requirements=[
        "langchain",
        "pydantic-settings",
    ],
)

# For local development: set in-cluster MinIO endpoint and redeploy
if mlrun.mlconf.is_ce_mode() and os.environ.get("AWS_ENDPOINT_URL_S3", "").startswith("http://localhost"):
    print("Setting in-cluster MinIO endpoint for CE mode and redeploying...")
    fn = project.get_function("langchain-monitoring-app")
    fn.set_env("AWS_ENDPOINT_URL_S3", "http://minio.mlrun.svc.cluster.local:9000")
    fn.deploy()
# Out:
# > 2026-02-03 18:44:04,704 [warning] It is recommended to use k8s secret (specify secret_name), specifying aws_access_key/aws_secret_key directly is unsafe.
# > 2026-02-03 18:44:04,705 [info] Starting remote function deploy
# 2026-02-03 16:44:04  (info) Deploying function
# 2026-02-03 16:44:04  (info) Building
# 2026-02-03 16:44:05  (info) Staging files and preparing base images
# 2026-02-03 16:44:05  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:44:05  (info) Building processor image
# 2026-02-03 16:46:00  (info) Build complete
# 2026-02-03 16:46:15  (info) Function deploy complete
# > 2026-02-03 18:46:16,242 [info] Model endpoint creation task completed with state succeeded
# > 2026-02-03 18:46:16,242 [info] Successfully deployed function: {"external_invocation_urls":["127.0.0.1:32063"],"internal_invocation_urls":["nuclio-langchain-mlrun-tutorial-langchain-monitoring-app.mlrun.svc.cluster.local:8080"]}
# Setting in-cluster MinIO endpoint for CE mode and redeploying...
# > 2026-02-03 18:46:16,301 [info] Starting remote function deploy
# 2026-02-03 16:46:16  (info) Deploying function
# 2026-02-03 16:46:16  (info) Building
# 2026-02-03 16:46:17  (info) Staging files and preparing base images
# 2026-02-03 16:46:17  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2026-02-03 16:46:17  (info) Building processor image
# 2026-02-03 16:48:22  (info) Build complete
# 2026-02-03 16:48:37  (info) Function deploy complete
# > 2026-02-03 18:48:37,774 [info] Model endpoint creation task completed with state succeeded
# > 2026-02-03 18:48:37,774 [info] Successfully deployed function: {"external_invocation_urls":["127.0.0.1:32063"],"internal_invocation_urls":["nuclio-langchain-mlrun-tutorial-langchain-monitoring-app.mlrun.svc.cluster.local:8080"]}

# %% [markdown]
# Once it is deployed, you can run events again and see the monitoring application in MLRun UI in action:
#
# ![mlrun ui example](./notebook_images/mlrun_ui.png)
